# %%
# 1. SETUP CODE (Pull latest from GitHub)
import os
REPO_DIR = "ssiu-fa-2026"
if not os.path.exists(REPO_DIR):
    # !git clone https://github.com/Default-ant/ssiu-fa-2026.git
else:
    # %cd {REPO_DIR}
    # !git pull origin main
    # %cd ..
# %cd {REPO_DIR}

# 2. DEFINITIVE KAGGLE PATHS (Verified from your live logs)
TRAIN_DATA = "/kaggle/input/datasets/guansuo/manga109/MANGA109"
VAL_SET5   = "/kaggle/input/datasets/chenqizhou/set5-hr-lr/Set5/HR"
VAL_SET14  = "/kaggle/input/datasets/guansuo/set14dataset/Set14/image_SRF_4"
VAL_BSD100 = "/kaggle/input/datasets/tulips99/bsd100/BSD100/image_SRF_4"
# Urban100 is deeply nested, using the 'HIGH x4' folder:
VAL_URBAN  = "/kaggle/input/datasets/harshraone/urban100/Urban 100/X4 Urban100/X4/HIGH x4 URban100"

# 3. START SOTA TRAINING
# This will now find the MANGA109 images correctly!
# !python train_ssiu.py --data_path "{TRAIN_DATA}" --iterations 8000

# 4. COMPREHENSIVE VALIDATION
print("\n=== Validating on Set5 ===")
# !python validate_ssiu.py --data_path "{VAL_SET5}"

print("\n=== Validating on Set14 ===")
# !python validate_ssiu.py --data_path "{VAL_SET14}"

print("\n=== Validating on BSD100 ===")
# !python validate_ssiu.py --data_path "{VAL_BSD100}"

print("\n=== Validating on Urban100 ===")
# !python validate_ssiu.py --data_path "{VAL_URBAN}"
# Out:
# Cloning into 'ssiu-fa-2026'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 21 (delta 9), reused 16 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (21/21), 9.04 KiB | 3.01 MiB/s, done.
# Resolving deltas: 100% (9/9), done.
# /kaggle/working/ssiu-fa-2026
# --- STARTING SOTA-PUSH SSIU-FA (2026) TRAINING ---
# Loading 109 images for high-performance training from /kaggle/input/datasets/guansuo/manga109/MANGA109... 🔥
# Ready! Training on full-resolution HR sources. ⚡
# 🚀 Speed: 0000/8000 (0%) | Loss: 0.6247 | LR: 0.001000
# 🚀 Speed: 0100/8000 (1%) | Loss: 0.0546 | LR: 0.001000
# 🚀 Speed: 0200/8000 (2%) | Loss: 0.0591 | LR: 0.000998
# 🚀 Speed: 0300/8000 (4%) | Loss: 0.0453 | LR: 0.000997
# 🚀 Speed: 0400/8000 (5%) | Loss: 0.0488 | LR: 0.000994
# 🚀 Speed: 0500/8000 (6%) | Loss: 0.0462 | LR: 0.000990
# 🚀 Speed: 0600/8000 (8%) | Loss: 0.0549 | LR: 0.000986
# ...
